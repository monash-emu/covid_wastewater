# %%
import pandas as pd
from wbe.constants import DATA_PATH
from wbe.inputs import get_storage_metadata

# %%
filename = "fips_lookup_d20260226_t204115_sha8b5688e.csv"
lookup = pd.read_csv(DATA_PATH / "jhu" / filename, index_col=0)["FIPS"].astype(str).str.zfill(5)
lookup.index = lookup.index.astype(str)

filename = "jhu_confirmed_d20260226_t065534_sha8e7d05f.csv"
case_data = pd.read_csv(DATA_PATH / "jhu" / filename, index_col=0)
case_data.index = pd.to_datetime(case_data.index)
case_data.columns = case_data.columns.map(lookup)
case_data = case_data.loc[:, ~case_data.columns.isna()]

filename = "jhu_deaths_d20260226_t065541_sha8e7d05f.csv"
death_data = pd.read_csv(DATA_PATH / "jhu" / filename, index_col=0)
death_data.index = pd.to_datetime(death_data.index)
death_data.columns = death_data.columns.map(lookup)
death_data = death_data.loc[:, ~death_data.columns.isna()]
